# %%
import webbrowser

html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Richphaela Early Childhood School</title>
    <style>
        body {
            margin: 0;
            font-family: Arial, sans-serif;
            background-color: #f4f7f8;
            color: #333;
        }

        header {
            background-color: #005580;
            color: white;
            padding: 20px 0;
            text-align: center;
        }

        nav {
            background-color: #00334d;
            padding: 10px 0;
            text-align: center;
        }

        nav a {
            color: white;
            margin: 0 15px;
            text-decoration: none;
            font-weight: bold;
        }

        .hero {
            background-color: #cce7ff;
            padding: 50px;
            text-align: center;
        }

        .hero h1 {
            font-size: 2.5em;
        }

        .section {
            padding: 40px 20px;
            max-width: 1000px;
            margin: auto;
        }

        .section h2 {
            color: #005580;
            margin-bottom: 10px;
        }

        .footer {
            background-color: #00334d;
            color: white;
            text-align: center;
            padding: 20px 10px;
            font-size: 0.9em;
        }

        .contact-info p {
            margin: 5px 0;
        }
    </style>
</head>
<body>

<header>
    <h1>Richphaela Early Childhood School, Ojodu</h1>
    <p>Building bright futures, one child at a time</p>
    <img src="richphaela_logo.jpeg" alt="Richphaela Logo" style="width: 100px; height: auto; margin-bottom: 10px;">
    <img src="school_building.jpg" alt="Classroom" style="width: 100%; border-radius: 10px;">

</header>

<nav>
    <a href="#about">About Us</a>
    <a href="#programs">Programs</a>
    <a href="#contact">Contact</a>
</nav>

<section class="hero">
    <h1>Welcome to Richphaela School</h1>
    <p>Where learning begins with love, care, and excellence.</p>
</section>

<section class="section" id="about">
    <h2>About Us</h2>
    <p>Richphaela Early Childhood School is committed to nurturing young minds in a safe, joyful, and stimulating environment. Our dedicated staff are passionate about early childhood education and work with parents to give every child a strong foundation in life.</p>
    <iframe width="560" height="315" src="https://www.youtube.com/watch?v=wkhQO7atf3w" title="Richphaela School Video" frameborder="0" allowfullscreen></iframe>
</section>

<section class="section" id="programs">
    <h2>Our Programs</h2>
    <ul>
        <li>Early Childhood Education (Creche, Nursery, and Primar)</li>
        <li>Literacy & Numeracy Development</li>
        <li>ICT & Coding Learning</li>
        <li>soccer  & Balle coaching</li>
        <li>Montessori & STEM Integration</li>
        <li>After School Programs</li>
    </ul>
</section>

<section class="section contact-info" id="contact">
    <h2>Contact Us</h2>
    <p><strong>Address:</strong> 7 Joel Odumosu Close, off Kashiman, Saabo, Ojodu, Ikeja, Lagos</p>
    <p><strong>Email:</strong> richphaela@gmail.com</p>
    <p><strong>Phone:</strong> +234 806 655 7655 +2348069102483</p>
</section>
<form action="mailto:richphaela@gmail.com" method="POST" enctype="text/plain">
    <label>Name:</label><br>
    <input type="text" name="name" required><br><br>

    <label>Email:</label><br>
    <input type="email" name="email" required><br><br>

    <label>Message:</label><br>
    <textarea name="message" rows="5" required></textarea><br><br>

    <input type="submit" value="Send Message">
</form>
<iframe 
  src="https://www.google.com/maps?q=Richphaela+School,+Ojodu+Berger,+Lagos&output=embed"
  width="100%" height="300" style="border:0;" allowfullscreen loading="lazy">
</iframe>

<footer class="footer">
    <p>© 2025 Richphaela Early Childhood School. All Rights Reserved.</p>
</footer>

</body>
</html>
'''

# Save to file
filename = 'Richphaela_School_page.html'
with open(filename, 'w', encoding='utf-8') as f:
    f.write(html_content)

# Open in browser
webbrowser.open_new_tab(filename)
# Out:
# True
